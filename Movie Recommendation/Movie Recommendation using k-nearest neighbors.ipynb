# %%
import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
from fuzzywuzzy import process
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
movies = 'movies.csv'
ratings = 'ratings.csv'

df_movies = pd.read_csv(movies, usecols=['movieId','title'], dtype={'movieId':'int32','title':'str'})
df_ratings= pd.read_csv(ratings, usecols=['userId','movieId','rating'],  dtype={'movieId':'int32','movieID':'int32','ratings':'float32'})

# %%
df_movies
# Out:
#       movieId                                              title
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# ...

# %%
movie_users = df_ratings.pivot(index='movieId', columns='userId',values='rating').fillna(0)
movie_users
mat_movies_users=csr_matrix(movie_users.values)

# %%
model_knn = NearestNeighbors(metric='cosine', algorithm = 'brute',n_neighbors=20)

# %%
model_knn.fit(mat_movies_users)
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=1, n_neighbors=20, p=2, radius=1.0)

# %%
#Recommender(movie_name) = List of Movies recommended

def recommender(movie_name, data, model, n_recommendation):
    model.fit(data)
    idx=process.extractOne(movie_name, df_movies['title'])[2]
    print('Movie Selected: ',df_movies['title'][idx],'Index: ',idx)
    print('Searching for recommendations.....')
    distances, indices=model.kneighbors(data[idx], n_neighbors=n_recommendation)
    for i in indices:
        print(df_movies['title'][i].where(i!=idx))
    
recommender('sabrina', mat_movies_users, model_knn,20)
# Out:
# Movie Selected:  Sabrina (1995) Index:  6
# Searching for recommendations.....
# 6                                             NaN
# 577           Truth About Cats & Dogs, The (1996)
# 4              Father of the Bride Part II (1995)
# 55                      Mr. Holland's Opus (1995)
# 116                          Birdcage, The (1996)
# 658                                Tin Cup (1996)
# 2                         Grumpier Old Men (1995)
# 546                    Mission: Impossible (1996)
# 16                   Sense and Sensibility (1995)
# 10                 American President, The (1995)
# 472                   Sleepless in Seattle (1993)
# 594                                Twister (1996)
# 815    Willy Wonka & the Chocolate Factory (1971)
# 33                        Dead Man Walking (1995)
# 51                   Home for the Holidays (1995)
# 47                        Mighty Aphrodite (1995)
# 434                 Much Ado About Nothing (1993)
# ...
